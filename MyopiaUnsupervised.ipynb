# %%
from sklearn.cluster import KMeans
from sklearn.manifold import TSNE
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt
import pandas as pd
from pathlib import Path

# %% [markdown]
# ### Part 1: Prepare the Data

# %%
df = pd.read_csv('myopia.csv')
df
# Out:
#      AGE  SPHEQ         AL    ACD     LT    VCD  SPORTHR  READHR  COMPHR  \
# 0      6 -0.052  21.889999  3.690  3.498  14.70       45       8       0
# 1      6  0.608  22.379999  3.702  3.392  15.29        4       0       1
# 2      6  1.179  22.490000  3.462  3.514  15.52       14       0       2
# 3      6  0.525  22.200001  3.862  3.612  14.73       18      11       0
# 4      5  0.697  23.290001  3.676  3.454  16.16       14       0       0
# ..   ...    ...        ...    ...    ...    ...      ...     ...     ...
# 613    6  0.678  22.400000  3.663  3.803  14.93        2       0       7
# 614    6  0.665  22.500000  3.570  3.378  15.56        6       0       1
# 615    6  1.834  22.940001  3.624  3.424  15.89        8       0       0
# 616    6  0.665  21.920000  3.688  3.598  14.64       12       2       1
# 617    6  0.802  22.260000  3.530  3.484  15.25       25       0       2
#
#      STUDYHR  TVHR  DIOPTERHR  MOMMY  DADMY  MYOPIC
# ...

# %%
labels = df['MYOPIC']
DropDf = df.drop('MYOPIC', axis=1)
DropDf
# Out:
#      AGE  SPHEQ         AL    ACD     LT    VCD  SPORTHR  READHR  COMPHR  \
# 0      6 -0.052  21.889999  3.690  3.498  14.70       45       8       0
# 1      6  0.608  22.379999  3.702  3.392  15.29        4       0       1
# 2      6  1.179  22.490000  3.462  3.514  15.52       14       0       2
# 3      6  0.525  22.200001  3.862  3.612  14.73       18      11       0
# 4      5  0.697  23.290001  3.676  3.454  16.16       14       0       0
# ..   ...    ...        ...    ...    ...    ...      ...     ...     ...
# 613    6  0.678  22.400000  3.663  3.803  14.93        2       0       7
# 614    6  0.665  22.500000  3.570  3.378  15.56        6       0       1
# 615    6  1.834  22.940001  3.624  3.424  15.89        8       0       0
# 616    6  0.665  21.920000  3.688  3.598  14.64       12       2       1
# 617    6  0.802  22.260000  3.530  3.484  15.25       25       0       2
#
#      STUDYHR  TVHR  DIOPTERHR  MOMMY  DADMY
# 0          0    10         34      1      1
# ...

# %%
#import Scaler
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

scaledData = scaler.fit_transform(DropDf)

scaledDF = pd.DataFrame(scaledData, columns = DropDf.columns[0:])
scaledDF
# Out:
#           AGE     SPHEQ        AL       ACD        LT       VCD   SPORTHR  \
# 0   -0.420219 -1.363917 -0.892861  0.483784 -0.281443 -1.019792  4.150661
# 1   -0.420219 -0.308612 -0.171840  0.535910 -0.967997 -0.130763 -0.998898
# 2   -0.420219  0.604386 -0.009977 -0.506628 -0.177812  0.215809  0.257092
# 3   -0.420219 -0.441325 -0.436703  1.230936  0.456927 -0.974587  0.759488
# 4   -1.823978 -0.166306  1.167204  0.422970 -0.566427  1.180178  0.257092
# ..        ...       ...       ...       ...       ...       ...       ...
# 613 -0.420219 -0.196686 -0.142410  0.366499  1.694021 -0.673220 -1.250096
# 614 -0.420219 -0.217472  0.004738 -0.037486 -1.058674  0.276082 -0.747700
# 615 -0.420219  1.651696  0.652187  0.197086 -0.760735  0.773335 -0.496502
# 616 -0.420219 -0.217472 -0.848716  0.475096  0.366251 -1.110201  0.005894
# 617 -0.420219  0.001583 -0.348415 -0.211242 -0.372120 -0.191036  1.638681
#
#        READHR    COMPHR   STUDYHR      TVHR  DIOPTERHR     MOMMY     DADMY
# ...

# %% [markdown]
# ### Part 2: Apply Dimensionality Reduction

# %%
# Initialize PCA model
pca = PCA(n_components=.90)

# Fit_transform Scaled Data
MyopicPCA = pca.fit_transform(scaledDF)

# Get the explained variance ratio
pca.explained_variance_ratio_.sum()
# Out:
# 0.9187361702915187

# %%
# Initialize t-SNE model
tsne = TSNE(learning_rate=35, perplexity = 50)

# Reduce dimensions
tsneFeatures = tsne.fit_transform(MyopicPCA)

# %%
plt.scatter(tsneFeatures[:,0],tsneFeatures[:,1], c=labels)

print('There is no distinct cluster, the results are mixed into each other')
# Out:
# There is no distinct cluster, the results are mixed into each other

# %% [markdown]
# ### Part 3: Perform a Cluster Analysis with K-means

# %%
# Identify the best number of clusters using the elbow curve
inertia = []
k = list(range(1,11))


# Looking for the best k
for i in k:
    model = KMeans(n_clusters=i, random_state=42)
    model.fit(MyopicPCA)
    inertia.append(model.inertia_)
    
elbow = {"k": k, "inertia": inertia}
elbowDF = pd.DataFrame(elbow)
elbowDF
# Out:
# C:\Users\johnm\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:881: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=3.
#   warnings.warn(
#     k      inertia
# 0   1  7948.905345
# 1   2  6794.293482
# 2   3  6030.953812
# 3   4  5662.799045
# 4   5  5381.970825
# 5   6  5127.751086
# 6   7  4926.212042
# 7   8  4741.864184
# 8   9  4585.604309
# 9  10  4458.846628

# %%
plt.plot(k, inertia)
plt.xticks(range(1,11, 1))
plt.ylabel('Inertia')
plt.xlabel('Clusters (k)')
# Out:
# Text(0.5, 0, 'Clusters (k)')

# %%
def get_clusters(k, data):
    model = KMeans(n_clusters=k, random_state=42)
    model.fit(data)
    predict = model.predict(data)
    data['classification'] = model.labels_
    return data

# %%
MyopicPCADF = pd.DataFrame(MyopicPCA)
MyopicPCADF
# Out:
#             0         1         2         3         4         5         6  \
# 0    0.535503  1.145004 -1.385019  0.116006 -3.226691 -1.928459 -1.958892
# 1   -0.624706 -1.575786 -0.794253  1.156287  0.292256  0.349060 -0.455206
# 2   -0.933479 -0.717076  0.820150 -1.547638  0.173941  0.272783  0.025821
# 3    0.106354  1.192475 -0.024441  1.507469 -2.356836 -0.023139  0.236418
# 4   -0.388503 -2.839655 -0.229767 -0.622510  0.271458 -0.928956  0.537900
# ..        ...       ...       ...       ...       ...       ...       ...
# 613 -0.237547  1.146547 -1.546054 -0.248834  2.326683 -0.202403  0.084104
# 614 -0.649011 -1.796952 -0.823592  0.564878  0.134282  0.348639 -0.174354
# 615 -0.890082 -2.308005  0.268102  0.262770  0.231606  0.566061 -0.328287
# 616 -1.124000  0.451890  0.001659 -0.847089 -0.143347 -0.414353 -0.448120
# 617 -0.691534 -0.737046 -1.052900 -0.502772 -0.882590 -0.231183 -1.447594
#
#             7         8         9
# 0   -1.922997  0.026753  0.178144
# ...

# %%
clusters = get_clusters(3, MyopicPCADF)
clusters
# Out:
#             0         1         2         3         4         5         6  \
# 0    0.535503  1.145004 -1.385019  0.116006 -3.226691 -1.928459 -1.958892
# 1   -0.624706 -1.575786 -0.794253  1.156287  0.292256  0.349060 -0.455206
# 2   -0.933479 -0.717076  0.820150 -1.547638  0.173941  0.272783  0.025821
# 3    0.106354  1.192475 -0.024441  1.507469 -2.356836 -0.023139  0.236418
# 4   -0.388503 -2.839655 -0.229767 -0.622510  0.271458 -0.928956  0.537900
# ..        ...       ...       ...       ...       ...       ...       ...
# 613 -0.237547  1.146547 -1.546054 -0.248834  2.326683 -0.202403  0.084104
# 614 -0.649011 -1.796952 -0.823592  0.564878  0.134282  0.348639 -0.174354
# 615 -0.890082 -2.308005  0.268102  0.262770  0.231606  0.566061 -0.328287
# 616 -1.124000  0.451890  0.001659 -0.847089 -0.143347 -0.414353 -0.448120
# 617 -0.691534 -0.737046 -1.052900 -0.502772 -0.882590 -0.231183 -1.447594
#
#             7         8         9  classification
# ...

# %%
def show_clusters(MyopicPCADF):
    plt.scatter(MyopicPCADF[0], MyopicPCADF[1], c=MyopicPCADF['classification'])
    plt.xlabel('PCA 1')
    plt.ylabel('PCA 2')
    plt.show()
    
show_clusters(MyopicPCADF)

# %% [markdown]
# ### Part 4: Recommendation
#
# There are clear recommendations to study our patients.
#
# Using TSNE is not a viable option to cluster our patients to study. The correct method is to use PCA and a Cluster Analysis using K-Means. This will lead to seeing three clear clusters of patients to study.
#
# It would be interesting to see if these clusters hold as the sample size grows.
